# %%
import pandas as pd
import numpy as np
import math

# %%
udemy_df=pd.read_csv("udemy_output_All_IT__Software_p1_p626.csv")

# %%
udemy_df
# Out:
#             id                                              title  \
# 0       762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3       648826         The Complete Financial Analyst Course 2020
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...
# ...        ...                                                ...
# 22848  1516977  Fundamental Service Oriented Arch (SOA) Securi...
# 22849  1479824  Linux Certification for Experts - Practice Tes...
# 22850  1879598  SAP SuccessFactors Employee Central Payroll Fu...
# 22851  1940616                  Comptia Linux+ / LPIC-1 (102-400)
# 22852   543712                    Cisco Networking CCNA IPv6 OSPF
#
#                                                      url  is_paid  \
# 0                     /course/the-complete-sql-bootcamp/     True
# ...

# %%
udemy_head=udemy_df.head()

# %%
udemy_head
# Out:
#         id                                              title  \
# 0   762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1   937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2  1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3   648826         The Complete Financial Analyst Course 2020
# 4   637930  An Entire MBA in 1 Course:Award Winning Busine...
#
#                                                  url  is_paid  \
# 0                 /course/the-complete-sql-bootcamp/     True
# 1                                 /course/tableau10/     True
# 2                        /course/pmp-pmbok6-35-pdus/     True
# 3     /course/the-complete-financial-analyst-course/     True
# 4  /course/an-entire-mba-in-1-courseaward-winning...     True
#
#    num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 0           295509     4.66019            4.67874  4.67874        78006
# ...

# %%
udemy_tail=udemy_df.tail()

# %%
udemy_tail
# Out:
#             id                                              title  \
# 22848  1516977  Fundamental Service Oriented Arch (SOA) Securi...
# 22849  1479824  Linux Certification for Experts - Practice Tes...
# 22850  1879598  SAP SuccessFactors Employee Central Payroll Fu...
# 22851  1940616                  Comptia Linux+ / LPIC-1 (102-400)
# 22852   543712                    Cisco Networking CCNA IPv6 OSPF
#
#                                                      url  is_paid  \
# 22848  /course/fundamental-service-oriented-arch-soa-...     True
# 22849  /course/linux-certification-for-beginners-prac...     True
# 22850       /course/public-transport-management-systems/     True
# 22851              /course/comptia-linux-lpic-1-102-400/     True
# 22852            /course/networkingstepbystep-ipv6-ospf/     True
#
#        num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 22848               16        3.25            2.65702  2.65702            2
# ...

# %%
udemy_info=udemy_df.info

# %%
udemy_info
# Out:
# <bound method DataFrame.info of             id                                              title  \
# 0       762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3       648826         The Complete Financial Analyst Course 2020
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...
# ...        ...                                                ...
# 22848  1516977  Fundamental Service Oriented Arch (SOA) Securi...
# 22849  1479824  Linux Certification for Experts - Practice Tes...
# 22850  1879598  SAP SuccessFactors Employee Central Payroll Fu...
# 22851  1940616                  Comptia Linux+ / LPIC-1 (102-400)
# 22852   543712                    Cisco Networking CCNA IPv6 OSPF
#
#                                                      url  is_paid  \
# 0                     /course/the-complete-sql-bootcamp/     True
# ...

# %%
udemy_describe=udemy_df.describe

# %%
udemy_df
# Out:
#             id                                              title  \
# 0       762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3       648826         The Complete Financial Analyst Course 2020
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...
# ...        ...                                                ...
# 22848  1516977  Fundamental Service Oriented Arch (SOA) Securi...
# 22849  1479824  Linux Certification for Experts - Practice Tes...
# 22850  1879598  SAP SuccessFactors Employee Central Payroll Fu...
# 22851  1940616                  Comptia Linux+ / LPIC-1 (102-400)
# 22852   543712                    Cisco Networking CCNA IPv6 OSPF
#
#                                                      url  is_paid  \
# 0                     /course/the-complete-sql-bootcamp/     True
# ...

# %%
udemy_df.rating
# Out:
# 0        4.67874
# 1        4.60015
# 2        4.59326
# 3        4.53772
# 4        4.47173
#           ...
# 22848    2.65702
# 22849    3.56818
# 22850    2.70354
# 22851    3.72059
# 22852    4.48220
# Name: rating, Length: 22853, dtype: float64

# %%
udemy_df[["created","published_time","discount_price__currency"]]
# Out:
#                     created        published_time discount_price__currency
# 0      2016-02-14T22:57:48Z  2016-04-06T05:16:11Z                      INR
# 1      2016-08-22T12:10:18Z  2016-08-23T16:59:49Z                      INR
# 2      2017-09-26T16:32:48Z  2017-11-14T23:58:14Z                      INR
# 3      2015-10-23T13:34:35Z  2016-01-21T01:38:48Z                      INR
# 4      2015-10-12T06:39:46Z  2016-01-11T21:39:33Z                      INR
# ...                     ...                   ...                      ...
# 22848  2018-01-19T09:03:46Z  2018-01-28T09:20:37Z                      INR
# 22849  2017-12-23T12:44:39Z  2017-12-24T07:38:36Z                      INR
# 22850  2018-08-27T14:43:42Z  2018-09-19T23:19:18Z                      NaN
# 22851  2018-09-30T15:11:27Z  2018-12-11T16:22:32Z                      INR
# 22852  2015-07-03T02:24:30Z  2015-07-07T00:01:23Z                      INR
#
# [22853 rows x 3 columns]

# %%
udemy_df.iloc[1]
# Out:
# id                                                                         937678
# title                           Tableau 2020 A-Z: Hands-On Tableau Training fo...
# url                                                            /course/tableau10/
# is_paid                                                                      True
# num_subscribers                                                            209070
# avg_rating                                                                4.58956
# avg_rating_recent                                                         4.60015
# rating                                                                    4.60015
# num_reviews                                                                 54581
# is_wishlisted                                                               False
# num_published_lectures                                                         78
# ...

# %%
udemy_df.iloc[1:-1]
# Out:
#             id                                              title  \
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3       648826         The Complete Financial Analyst Course 2020
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...
# 5      1208634  Microsoft Power BI - A Complete Introduction [...
# ...        ...                                                ...
# 22847  1949466                        Ethical Hacking Masterclass
# 22848  1516977  Fundamental Service Oriented Arch (SOA) Securi...
# 22849  1479824  Linux Certification for Experts - Practice Tes...
# 22850  1879598  SAP SuccessFactors Employee Central Payroll Fu...
# 22851  1940616                  Comptia Linux+ / LPIC-1 (102-400)
#
#                                                      url  is_paid  \
# 1                                     /course/tableau10/     True
# ...

# %%
udemy_df.isnull()
# Out:
#           id  title    url  is_paid  num_subscribers  avg_rating  \
# 0      False  False  False    False            False       False
# 1      False  False  False    False            False       False
# 2      False  False  False    False            False       False
# 3      False  False  False    False            False       False
# 4      False  False  False    False            False       False
# ...      ...    ...    ...      ...              ...         ...
# 22848  False  False  False    False            False       False
# 22849  False  False  False    False            False       False
# 22850  False  False  False    False            False       False
# 22851  False  False  False    False            False       False
# 22852  False  False  False    False            False       False
#
#        avg_rating_recent  rating  num_reviews  is_wishlisted  \
# 0                  False   False        False          False
# ...

# %%
udemy_df.isnull().sum()
# Out:
# id                                 0
# title                              0
# url                                0
# is_paid                            0
# num_subscribers                    0
# avg_rating                         0
# avg_rating_recent                  0
# rating                             0
# num_reviews                        0
# is_wishlisted                      0
# num_published_lectures             0
# num_published_practice_tests       0
# created                            0
# published_time                     0
# discount_price__amount          1829
# discount_price__currency        1829
# discount_price__price_string    1829
# price_detail__amount             497
# price_detail__currency           497
# price_detail__price_string       497
# dtype: int64

# %%
udemy_df.isna()
# Out:
#           id  title    url  is_paid  num_subscribers  avg_rating  \
# 0      False  False  False    False            False       False
# 1      False  False  False    False            False       False
# 2      False  False  False    False            False       False
# 3      False  False  False    False            False       False
# 4      False  False  False    False            False       False
# ...      ...    ...    ...      ...              ...         ...
# 22848  False  False  False    False            False       False
# 22849  False  False  False    False            False       False
# 22850  False  False  False    False            False       False
# 22851  False  False  False    False            False       False
# 22852  False  False  False    False            False       False
#
#        avg_rating_recent  rating  num_reviews  is_wishlisted  \
# 0                  False   False        False          False
# ...

# %% [markdown]
# # 28/12/2022

# %%
from sklearn.preprocessing import LabelBinarizer,MultiLabelBinarizer

# %%
y=LabelBinarizer().fit_transform(udemy_df.is_paid)

# %%
y
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
udemy_df.head()
# Out:
#         id                                              title  \
# 0   762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1   937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2  1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3   648826         The Complete Financial Analyst Course 2020
# 4   637930  An Entire MBA in 1 Course:Award Winning Busine...
#
#                                                  url  is_paid  \
# 0                 /course/the-complete-sql-bootcamp/     True
# 1                                 /course/tableau10/     True
# 2                        /course/pmp-pmbok6-35-pdus/     True
# 3     /course/the-complete-financial-analyst-course/     True
# 4  /course/an-entire-mba-in-1-courseaward-winning...     True
#
#    num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 0           295509     4.66019            4.67874  4.67874        78006
# ...

# %%
l_encode=LabelBinarizer()
encode_df=pd.DataFrame(l_encode.fit_transform(udemy_df.is_paid))

# %%
encode_df
# Out:
#        0
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# ...   ..
# 22848  1
# 22849  1
# 22850  1
# 22851  1
# 22852  1
#
# [22853 rows x 1 columns]

# %%
final_df=udemy_df.join(encode_df)

# %%
final_df
# Out:
#             id                                              title  \
# 0       762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3       648826         The Complete Financial Analyst Course 2020
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...
# ...        ...                                                ...
# 22848  1516977  Fundamental Service Oriented Arch (SOA) Securi...
# 22849  1479824  Linux Certification for Experts - Practice Tes...
# 22850  1879598  SAP SuccessFactors Employee Central Payroll Fu...
# 22851  1940616                  Comptia Linux+ / LPIC-1 (102-400)
# 22852   543712                    Cisco Networking CCNA IPv6 OSPF
#
#                                                      url  is_paid  \
# 0                     /course/the-complete-sql-bootcamp/     True
# ...

# %%
#MAPPING OF ORDINAL Categorical variable

# %%
#step:1 perform unique operation

# %%
udemy_df["is_paid"].unique()
# Out:
# array([ True, False])

# %%
#step 2 create a mapping

# %%
udemy_df_map={"True":1,"False":2}

# %%
#add to column

# %%
udemy_df["is_paid"].replace(udemy_df_map)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 22848    True
# 22849    True
# 22850    True
# 22851    True
# 22852    True
# Name: is_paid, Length: 22853, dtype: bool

# %%
udemy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22853 entries, 0 to 22852
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            22853 non-null  int64
#  1   title                         22853 non-null  object
#  2   url                           22853 non-null  object
#  3   is_paid                       22853 non-null  bool
#  4   num_subscribers               22853 non-null  int64
#  5   avg_rating                    22853 non-null  float64
#  6   avg_rating_recent             22853 non-null  float64
#  7   rating                        22853 non-null  float64
#  8   num_reviews                   22853 non-null  int64
#  9   is_wishlisted                 22853 non-null  bool
#  10  num_published_lectures        22853 non-null  int64
#  11  num_published_practice_tests  22853 non-null  int64
# ...

# %% [markdown]
# # 29/12/2022

# %%
#missing value

# %%
#checking for missing for value

# %%
udemy_df.isnull().sum()
# Out:
# id                                 0
# title                              0
# url                                0
# is_paid                            0
# num_subscribers                    0
# avg_rating                         0
# avg_rating_recent                  0
# rating                             0
# num_reviews                        0
# is_wishlisted                      0
# num_published_lectures             0
# num_published_practice_tests       0
# created                            0
# published_time                     0
# discount_price__amount          1829
# discount_price__currency        1829
# discount_price__price_string    1829
# price_detail__amount             497
# price_detail__currency           497
# price_detail__price_string       497
# dtype: int64

# %%
#replcace missing value with 0
new_udemy_df1=udemy_df.fillna(0)

# %%
#fill with forward fill value
new_udemy_df2=udemy_df.fillna(method="ffill")

# %%
new_udemy_df2.isnull().sum()
# Out:
# id                              0
# title                           0
# url                             0
# is_paid                         0
# num_subscribers                 0
# avg_rating                      0
# avg_rating_recent               0
# rating                          0
# num_reviews                     0
# is_wishlisted                   0
# num_published_lectures          0
# num_published_practice_tests    0
# created                         0
# published_time                  0
# discount_price__amount          0
# discount_price__currency        0
# discount_price__price_string    0
# price_detail__amount            0
# price_detail__currency          0
# price_detail__price_string      0
# dtype: int64

# %%
#Set forward fill limit to 1
new_udemy_df3=udemy_df.fillna(method="ffill",limit=1)

# %%
#fill NAN value in backward direction
new_udemy_df4=udemy_df.fillna(method="bfill")

# %%
#interpolation of missing values
new_udemy_df5=udemy_df.interpolate()

# %%
#Drop Na dropna()
new_udemy_df=udemy_df.dropna()

# %%
#drop all rows having nan
new_udemy_df=udemy_df.dropna(how='all', inplace=True)

# %%
new_udemy_df1.head()
# Out:
#         id                                              title  \
# 0   762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1   937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2  1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3   648826         The Complete Financial Analyst Course 2020
# 4   637930  An Entire MBA in 1 Course:Award Winning Busine...
#
#                                                  url  is_paid  \
# 0                 /course/the-complete-sql-bootcamp/     True
# 1                                 /course/tableau10/     True
# 2                        /course/pmp-pmbok6-35-pdus/     True
# 3     /course/the-complete-financial-analyst-course/     True
# 4  /course/an-entire-mba-in-1-courseaward-winning...     True
#
#    num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 0           295509     4.66019            4.67874  4.67874        78006
# ...

# %%
new_udemy_df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [268], in <cell line: 1>()
# ----> 1 new_udemy_df.isnull().sum()
#
# AttributeError: 'NoneType' object has no attribute 'isnull'
